# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from math import sqrt

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import Adam

# %%
# Membaca file CSV
df = pd.read_csv('data_harga_beras.csv')
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date').interpolate(method='linear').reset_index()

# %%
# Drop kolom yang tidak digunakan
df = df.drop(['C4Medium','Bulog'], axis=1)
df = df.filter(['C4Super'])
df = df.values.astype('float32')

# %%
# Normalisasi data dengan range [0, 1] sebelum membagi data
scaler_0_1 = MinMaxScaler(feature_range=(0, 1))
df_normalized_0_1 = scaler_0_1.fit_transform(df)

scaler_neg1_1 = MinMaxScaler(feature_range=(-1, 1))
df_normalized_neg1_1 = scaler_neg1_1.fit_transform(df)

# %%
# Fungsi untuk menyiapkan data
def prepare_data(df, timesteps):
    X, Y = [], []
    for i in range(len(df) - timesteps - 1):
        X.append(df[i:(i + timesteps)])
        Y.append(df[i + timesteps, 0])
    return np.array(X), np.array(Y)

# %%
# Fungsi untuk membangun dan melatih model
def build_and_train_model(df_normalized, timesteps=1, num_neuron=10, num_epoch=50, num_batch=16):
    # Split data menjadi training dan testing
    n_samples = len(df_normalized)
    train_size = int(n_samples * 0.8)
    test_size = n_samples - train_size

    train_data = df_normalized[:train_size]
    test_data = df_normalized[train_size:]
    
    # Persiapan data
    X_train, Y_train = prepare_data(train_data, timesteps)
    X_test, Y_test = prepare_data(test_data, timesteps)

    # Reshape data
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

    # Build model
    model = Sequential()
    model.add(LSTM(4, activation='tanh', recurrent_activation='sigmoid', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(num_neuron, activation='tanh', recurrent_activation='sigmoid', return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(1, bias_initializer='zeros'))
    
    # Compile model
    adam_optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=adam_optimizer, loss='mse', metrics=['MAPE'])
    
    # Train model
    history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=num_epoch, batch_size=num_batch, verbose=1)
    
    return model, X_test, Y_test, history

# %%
# Normalisasi dengan range [0, 1]
model_0_1, X_test_0_1, Y_test_0_1, history_0_1 = build_and_train_model(df_normalized_0_1)

# Normalisasi dengan range [-1, 1]
model_neg1_1, X_test_neg1_1, Y_test_neg1_1, history_neg1_1 = build_and_train_model(df_normalized_neg1_1)
# Out:
# Epoch 1/50
# C:\Users\Windows\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - MAPE: 86776.8359 - loss: 0.0244 - val_MAPE: 79.9773 - val_loss: 0.3662
# Epoch 2/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 133367.3438 - loss: 0.0130 - val_MAPE: 72.9479 - val_loss: 0.3074
# Epoch 3/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAPE: 537626.8125 - loss: 0.0126 - val_MAPE: 68.6956 - val_loss: 0.2720
# Epoch 4/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 610155.6875 - loss: 0.0109 - val_MAPE: 61.2297 - val_loss: 0.2145
# Epoch 5/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAPE: 436824.2500 - loss: 0.0082 - val_MAPE: 43.6617 - val_loss: 0.1085
# Epoch 6/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAPE: 218370.7344 - loss: 0.0054 - val_MAPE: 25.6126 - val_loss: 0.0358
# Epoch 7/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 168281.2344 - loss: 0.0027 - val_MAPE: 6.0769 - val_loss: 0.0020
# Epoch 8/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAPE: 199024.9531 - loss: 0.0022 - val_MAPE: 3.4322 - val_loss: 0.0012
# Epoch 9/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAPE: 167072.5938 - loss: 0.0019 - val_MAPE: 5.8994 - val_loss: 0.0033
# Epoch 10/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 14469.1172 - loss: 0.0019 - val_MAPE: 3.9502 - val_loss: 0.0016
# Epoch 11/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAPE: 49097.4141 - loss: 0.0018 - val_MAPE: 5.7739 - val_loss: 0.0033
# Epoch 12/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - MAPE: 28997.0508 - loss: 0.0018 - val_MAPE: 6.3251 - val_loss: 0.0038
# Epoch 13/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 59300.2617 - loss: 0.0017 - val_MAPE: 6.6966 - val_loss: 0.0041
# Epoch 14/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 65354.4023 - loss: 0.0016 - val_MAPE: 5.4008 - val_loss: 0.0029
# Epoch 15/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 42051.7656 - loss: 0.0017 - val_MAPE: 4.6608 - val_loss: 0.0022
# Epoch 16/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 75907.6172 - loss: 0.0014 - val_MAPE: 6.7685 - val_loss: 0.0041
# Epoch 17/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 98753.6953 - loss: 0.0014 - val_MAPE: 5.7558 - val_loss: 0.0031
# Epoch 18/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 103258.7578 - loss: 0.0015 - val_MAPE: 9.2033 - val_loss: 0.0066
# Epoch 19/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 69881.4062 - loss: 0.0016 - val_MAPE: 7.3278 - val_loss: 0.0044
# Epoch 20/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 269461.4375 - loss: 0.0012 - val_MAPE: 6.3122 - val_loss: 0.0035
# Epoch 21/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 36541.3086 - loss: 0.0012 - val_MAPE: 7.4828 - val_loss: 0.0045
# Epoch 22/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 157778.6719 - loss: 0.0014 - val_MAPE: 5.0308 - val_loss: 0.0024
# Epoch 23/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 58840.3672 - loss: 0.0013 - val_MAPE: 5.6747 - val_loss: 0.0027
# Epoch 24/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 305514.3750 - loss: 0.0013 - val_MAPE: 4.3985 - val_loss: 0.0018
# Epoch 25/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 141319.1250 - loss: 0.0014 - val_MAPE: 4.9601 - val_loss: 0.0022
# Epoch 26/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 103989.0938 - loss: 0.0015 - val_MAPE: 4.7001 - val_loss: 0.0019
# Epoch 27/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 200464.0625 - loss: 0.0015 - val_MAPE: 5.1691 - val_loss: 0.0022
# Epoch 28/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 267418.6562 - loss: 0.0013 - val_MAPE: 2.9030 - val_loss: 8.0366e-04
# Epoch 29/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 150557.2344 - loss: 0.0015 - val_MAPE: 2.2783 - val_loss: 4.7805e-04
# Epoch 30/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 58530.0234 - loss: 0.0013 - val_MAPE: 2.5540 - val_loss: 6.2791e-04
# Epoch 31/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 115386.2031 - loss: 0.0014 - val_MAPE: 1.9740 - val_loss: 3.6307e-04
# Epoch 32/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 24984.2246 - loss: 0.0014 - val_MAPE: 1.9768 - val_loss: 3.6552e-04
# Epoch 33/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 58502.1523 - loss: 0.0013 - val_MAPE: 2.5402 - val_loss: 5.7363e-04
# Epoch 34/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 14985.1875 - loss: 0.0012 - val_MAPE: 1.9632 - val_loss: 3.8132e-04
# Epoch 35/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 300502.1562 - loss: 0.0014 - val_MAPE: 1.8159 - val_loss: 3.3866e-04
# Epoch 36/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 119152.9844 - loss: 0.0012 - val_MAPE: 1.6569 - val_loss: 3.1172e-04
# Epoch 37/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 41128.5312 - loss: 0.0016 - val_MAPE: 1.5787 - val_loss: 2.9369e-04
# Epoch 38/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 19562.0293 - loss: 0.0013 - val_MAPE: 2.7051 - val_loss: 5.3912e-04
# Epoch 39/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 114008.1562 - loss: 0.0012 - val_MAPE: 2.9317 - val_loss: 6.3246e-04
# Epoch 40/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 32890.5820 - loss: 0.0011 - val_MAPE: 3.1768 - val_loss: 7.1008e-04
# Epoch 41/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 49670.7500 - loss: 0.0012 - val_MAPE: 2.8986 - val_loss: 6.3469e-04
# Epoch 42/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 92161.9766 - loss: 0.0017 - val_MAPE: 3.1116 - val_loss: 7.2755e-04
# Epoch 43/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 149705.2500 - loss: 0.0012 - val_MAPE: 3.8289 - val_loss: 0.0011
# Epoch 44/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 167578.1562 - loss: 0.0018 - val_MAPE: 3.9110 - val_loss: 0.0011
# Epoch 45/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 29904.5645 - loss: 9.7256e-04 - val_MAPE: 4.1337 - val_loss: 0.0013
# Epoch 46/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 144519.8125 - loss: 0.0013 - val_MAPE: 1.9320 - val_loss: 4.2394e-04
# Epoch 47/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 20872.9746 - loss: 0.0013 - val_MAPE: 6.8357 - val_loss: 0.0032
# Epoch 48/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 35142.3320 - loss: 0.0012 - val_MAPE: 6.0156 - val_loss: 0.0026
# Epoch 49/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 88880.5938 - loss: 0.0015 - val_MAPE: 7.1806 - val_loss: 0.0036
# Epoch 50/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 255619.3906 - loss: 0.0014 - val_MAPE: 4.9305 - val_loss: 0.0019
# Epoch 1/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - MAPE: 93.2477 - loss: 0.5219 - val_MAPE: 142.2843 - val_loss: 0.4120
# Epoch 2/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 65.5602 - loss: 0.3107 - val_MAPE: 203.5983 - val_loss: 0.6078
# Epoch 3/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 45.2359 - loss: 0.1097 - val_MAPE: 256.0566 - val_loss: 0.7968
# Epoch 4/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 43.9262 - loss: 0.0523 - val_MAPE: 259.3868 - val_loss: 0.8034
# Epoch 5/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 45.8827 - loss: 0.0504 - val_MAPE: 251.1956 - val_loss: 0.7660
# Epoch 6/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 40.8793 - loss: 0.0466 - val_MAPE: 247.0536 - val_loss: 0.7431
# Epoch 7/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 49.8393 - loss: 0.0476 - val_MAPE: 239.9539 - val_loss: 0.7100
# Epoch 8/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 36.7195 - loss: 0.0421 - val_MAPE: 230.8478 - val_loss: 0.6712
# Epoch 9/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 33.1130 - loss: 0.0388 - val_MAPE: 221.3603 - val_loss: 0.6329
# Epoch 10/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 39.1439 - loss: 0.0370 - val_MAPE: 213.5526 - val_loss: 0.5994
# Epoch 11/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 37.6118 - loss: 0.0359 - val_MAPE: 204.5329 - val_loss: 0.5658
# Epoch 12/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 32.4911 - loss: 0.0347 - val_MAPE: 197.4494 - val_loss: 0.5385
# Epoch 13/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 29.8176 - loss: 0.0282 - val_MAPE: 188.3621 - val_loss: 0.5060
# Epoch 14/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 29.0538 - loss: 0.0266 - val_MAPE: 180.4417 - val_loss: 0.4780
# Epoch 15/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 26.0526 - loss: 0.0259 - val_MAPE: 172.3401 - val_loss: 0.4512
# Epoch 16/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 24.8183 - loss: 0.0230 - val_MAPE: 165.1758 - val_loss: 0.4282
# Epoch 17/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 22.2649 - loss: 0.0215 - val_MAPE: 159.6048 - val_loss: 0.4120
# Epoch 18/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 22.3190 - loss: 0.0208 - val_MAPE: 154.6993 - val_loss: 0.3970
# Epoch 19/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 21.8012 - loss: 0.0187 - val_MAPE: 149.5315 - val_loss: 0.3839
# Epoch 20/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 18.3537 - loss: 0.0164 - val_MAPE: 145.7992 - val_loss: 0.3719
# Epoch 21/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 17.6654 - loss: 0.0157 - val_MAPE: 140.5648 - val_loss: 0.3580
# Epoch 22/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 18.2035 - loss: 0.0157 - val_MAPE: 141.1746 - val_loss: 0.3591
# Epoch 23/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.9977 - loss: 0.0152 - val_MAPE: 138.3762 - val_loss: 0.3524
# Epoch 24/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 16.8463 - loss: 0.0131 - val_MAPE: 135.2962 - val_loss: 0.3444
# Epoch 25/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.4383 - loss: 0.0127 - val_MAPE: 133.8927 - val_loss: 0.3408
# Epoch 26/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.9831 - loss: 0.0122 - val_MAPE: 135.0753 - val_loss: 0.3450
# Epoch 27/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 16.4688 - loss: 0.0127 - val_MAPE: 134.1892 - val_loss: 0.3416
# Epoch 28/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.1137 - loss: 0.0133 - val_MAPE: 132.4155 - val_loss: 0.3374
# Epoch 29/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 14.7598 - loss: 0.0104 - val_MAPE: 130.3906 - val_loss: 0.3329
# Epoch 30/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.0269 - loss: 0.0107 - val_MAPE: 131.5402 - val_loss: 0.3350
# Epoch 31/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.9567 - loss: 0.0107 - val_MAPE: 133.7983 - val_loss: 0.3426
# Epoch 32/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 16.7290 - loss: 0.0101 - val_MAPE: 133.2395 - val_loss: 0.3413
# Epoch 33/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 14.6010 - loss: 0.0090 - val_MAPE: 131.0924 - val_loss: 0.3332
# Epoch 34/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.3653 - loss: 0.0100 - val_MAPE: 127.6888 - val_loss: 0.3226
# Epoch 35/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 14.3252 - loss: 0.0091 - val_MAPE: 129.9662 - val_loss: 0.3296
# Epoch 36/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 14.8854 - loss: 0.0107 - val_MAPE: 128.5958 - val_loss: 0.3259
# Epoch 37/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 14.9150 - loss: 0.0084 - val_MAPE: 127.6079 - val_loss: 0.3220
# Epoch 38/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.0744 - loss: 0.0102 - val_MAPE: 127.1381 - val_loss: 0.3205
# Epoch 39/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.2614 - loss: 0.0092 - val_MAPE: 124.9678 - val_loss: 0.3126
# Epoch 40/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 14.2575 - loss: 0.0086 - val_MAPE: 129.0692 - val_loss: 0.3254
# Epoch 41/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 14.3761 - loss: 0.0084 - val_MAPE: 129.9612 - val_loss: 0.3269
# Epoch 42/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 14.2033 - loss: 0.0082 - val_MAPE: 127.9594 - val_loss: 0.3209
# Epoch 43/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.9329 - loss: 0.0089 - val_MAPE: 128.5492 - val_loss: 0.3218
# Epoch 44/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 16.9674 - loss: 0.0092 - val_MAPE: 128.2600 - val_loss: 0.3209
# Epoch 45/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.3954 - loss: 0.0088 - val_MAPE: 128.9783 - val_loss: 0.3224
# Epoch 46/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 17.5821 - loss: 0.0097 - val_MAPE: 127.8442 - val_loss: 0.3175
# Epoch 47/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - MAPE: 13.7137 - loss: 0.0075 - val_MAPE: 127.8576 - val_loss: 0.3183
# Epoch 48/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 14.3528 - loss: 0.0081 - val_MAPE: 124.1786 - val_loss: 0.3075
# Epoch 49/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.5684 - loss: 0.0077 - val_MAPE: 125.5265 - val_loss: 0.3098
# Epoch 50/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.0094 - loss: 0.0072 - val_MAPE: 129.5702 - val_loss: 0.3205

# %%
# Evaluasi model sebelum denormalisasi
def evaluate_model_before_denormalization(model, X_test, Y_test):
    # Predict
    test_predict = model.predict(X_test, verbose=0)

    # Calculate metrics
    mae = mean_absolute_error(Y_test, test_predict)
    rmse = sqrt(mean_squared_error(Y_test, test_predict))
    mape = mean_absolute_percentage_error(Y_test, test_predict) * 100

    return mae, rmse, mape, Y_test, test_predict

# %%
# Evaluasi model untuk kedua skala
mae_0_1, rmse_0_1, mape_0_1, Y_test_0_1, test_predict_0_1 = evaluate_model_before_denormalization(model_0_1, X_test_0_1, Y_test_0_1)
mae_neg1_1, rmse_neg1_1, mape_neg1_1, Y_test_neg1_1, test_predict_neg1_1 = evaluate_model_before_denormalization(model_neg1_1, X_test_neg1_1, Y_test_neg1_1)

# Print hasil evaluasi
print(f"Interval [0, 1] -> RMSE: {rmse_0_1}, MAPE: {mape_0_1}%")
print(f"Interval [-1, 1] -> RMSE: {rmse_neg1_1}, MAPE: {mape_neg1_1}%")
# Out:
# Interval [0, 1] -> RMSE: 0.04376130655125724, MAPE: 4.930485785007477%
# Interval [-1, 1] -> RMSE: 0.5661027818844274, MAPE: 129.57017421722412%
