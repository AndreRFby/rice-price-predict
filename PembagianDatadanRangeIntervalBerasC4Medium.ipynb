# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from math import sqrt

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
from tensorflow.keras.optimizers import Adam

# %%
# Membaca file CSV
df = pd.read_csv('data_harga_beras.csv')
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date').interpolate(method='linear').reset_index()

# %%
# Drop kolom yang tidak digunakan
df = df.drop(['C4Super', 'Bulog'], axis=1)
df = df.filter(['C4Medium'])
df = df.values.astype('float32')

# %%
# Normalisasi data dengan range [0, 1] sebelum membagi data
scaler_0_1 = MinMaxScaler(feature_range=(0, 1))
df_normalized_0_1 = scaler_0_1.fit_transform(df)

scaler_neg1_1 = MinMaxScaler(feature_range=(-1, 1))
df_normalized_neg1_1 = scaler_neg1_1.fit_transform(df)

# %%
# Fungsi untuk menyiapkan data
def prepare_data(df, timesteps):
    X, Y = [], []
    for i in range(len(df) - timesteps - 1):
        X.append(df[i:(i + timesteps)])
        Y.append(df[i + timesteps, 0])
    return np.array(X), np.array(Y)

# %%
# Fungsi untuk membangun dan melatih model
def build_and_train_model(df_normalized, timesteps=1, num_neuron=10, num_epoch=50, num_batch=16):
    # Split data menjadi training dan testing
    n_samples = len(df_normalized)
    train_size = int(n_samples * 0.7)
    test_size = n_samples - train_size

    train_data = df_normalized[:train_size]
    test_data = df_normalized[train_size:]
    
    # Persiapan data
    X_train, Y_train = prepare_data(train_data, timesteps)
    X_test, Y_test = prepare_data(test_data, timesteps)

    # Reshape data
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], X_train.shape[2]))
    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], X_test.shape[2]))

    # Build model
    model = Sequential()
    model.add(LSTM(4, activation='tanh', recurrent_activation='sigmoid', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Dropout(0.2))
    model.add(LSTM(num_neuron, activation='tanh', recurrent_activation='sigmoid', return_sequences=False))
    model.add(Dropout(0.2))
    model.add(Dense(1, bias_initializer='zeros'))
    
    # Compile model
    adam_optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=adam_optimizer, loss='mse', metrics=['MAPE'])
    
    # Train model
    history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=num_epoch, batch_size=num_batch, verbose=1)
    
    return model, X_test, Y_test, history

# %%
# Normalisasi dengan range [0, 1]
model_0_1, X_test_0_1, Y_test_0_1, history_0_1 = build_and_train_model(df_normalized_0_1)

# Normalisasi dengan range [-1, 1]
model_neg1_1, X_test_neg1_1, Y_test_neg1_1, history_neg1_1 = build_and_train_model(df_normalized_neg1_1)
# Out:
# Epoch 1/50
# C:\Users\Windows\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - MAPE: 470679.5938 - loss: 0.0155 - val_MAPE: 74.4401 - val_loss: 0.2603
# Epoch 2/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 1963864.2500 - loss: 0.0089 - val_MAPE: 68.9319 - val_loss: 0.2299
# Epoch 3/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 1878749.5000 - loss: 0.0085 - val_MAPE: 65.3256 - val_loss: 0.2069
# Epoch 4/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 2389088.7500 - loss: 0.0083 - val_MAPE: 61.9013 - val_loss: 0.1831
# Epoch 5/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 1580164.8750 - loss: 0.0076 - val_MAPE: 55.3427 - val_loss: 0.1449
# Epoch 6/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 1128604.5000 - loss: 0.0050 - val_MAPE: 44.9085 - val_loss: 0.0939
# Epoch 7/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 2332826.7500 - loss: 0.0039 - val_MAPE: 31.1087 - val_loss: 0.0424
# Epoch 8/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 750942.7500 - loss: 0.0032 - val_MAPE: 16.6704 - val_loss: 0.0108
# Epoch 9/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 706077.7500 - loss: 0.0018 - val_MAPE: 4.9787 - val_loss: 7.5384e-04
# Epoch 10/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 257777.5000 - loss: 0.0013 - val_MAPE: 4.1904 - val_loss: 5.8540e-04
# Epoch 11/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 434410.0625 - loss: 0.0011 - val_MAPE: 4.8172 - val_loss: 7.2599e-04
# Epoch 12/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 559303.6250 - loss: 0.0010 - val_MAPE: 4.6438 - val_loss: 0.0011
# Epoch 13/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 266605.8125 - loss: 0.0014 - val_MAPE: 5.3919 - val_loss: 0.0015
# Epoch 14/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 708067.9375 - loss: 0.0015 - val_MAPE: 5.8719 - val_loss: 0.0023
# Epoch 15/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 611852.4375 - loss: 0.0012 - val_MAPE: 4.9512 - val_loss: 9.1489e-04
# Epoch 16/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 748003.3750 - loss: 0.0010 - val_MAPE: 5.5077 - val_loss: 0.0019
# Epoch 17/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 542496.3125 - loss: 0.0011 - val_MAPE: 4.5325 - val_loss: 6.8626e-04
# Epoch 18/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 612797.5625 - loss: 0.0010 - val_MAPE: 4.0483 - val_loss: 6.3397e-04
# Epoch 19/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 467743.0312 - loss: 0.0011 - val_MAPE: 4.7033 - val_loss: 9.4815e-04
# Epoch 20/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 380622.5625 - loss: 9.1719e-04 - val_MAPE: 4.4110 - val_loss: 6.9420e-04
# Epoch 21/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 505244.4688 - loss: 9.5056e-04 - val_MAPE: 5.8465 - val_loss: 9.5151e-04
# Epoch 22/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 525105.6875 - loss: 0.0012 - val_MAPE: 4.9145 - val_loss: 0.0012
# Epoch 23/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 534392.1250 - loss: 0.0011 - val_MAPE: 4.0817 - val_loss: 7.3662e-04
# Epoch 24/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 187704.2031 - loss: 9.7882e-04 - val_MAPE: 3.6111 - val_loss: 4.6317e-04
# Epoch 25/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 410817.4688 - loss: 7.8860e-04 - val_MAPE: 3.9052 - val_loss: 6.0240e-04
# Epoch 26/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 420511.7188 - loss: 0.0010 - val_MAPE: 3.9962 - val_loss: 5.2198e-04
# Epoch 27/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 316960.8750 - loss: 0.0010 - val_MAPE: 3.5443 - val_loss: 4.7686e-04
# Epoch 28/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 840131.6875 - loss: 8.2311e-04 - val_MAPE: 3.4250 - val_loss: 5.0595e-04
# Epoch 29/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 407211.5312 - loss: 0.0010 - val_MAPE: 2.9788 - val_loss: 3.6411e-04
# Epoch 30/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 888686.5625 - loss: 0.0011 - val_MAPE: 2.4876 - val_loss: 3.3340e-04
# Epoch 31/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 506865.6250 - loss: 9.6410e-04 - val_MAPE: 2.9455 - val_loss: 3.7665e-04
# Epoch 32/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 276157.0312 - loss: 8.3755e-04 - val_MAPE: 3.2836 - val_loss: 4.0973e-04
# Epoch 33/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 425753.6562 - loss: 0.0013 - val_MAPE: 3.7442 - val_loss: 4.9527e-04
# Epoch 34/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 873078.6250 - loss: 0.0011 - val_MAPE: 5.2233 - val_loss: 9.4143e-04
# Epoch 35/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 597148.4375 - loss: 0.0010 - val_MAPE: 4.2254 - val_loss: 6.5005e-04
# Epoch 36/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 615803.3125 - loss: 9.2311e-04 - val_MAPE: 2.0378 - val_loss: 2.9883e-04
# Epoch 37/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 616758.5000 - loss: 8.6213e-04 - val_MAPE: 4.5619 - val_loss: 8.0989e-04
# Epoch 38/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 639271.8125 - loss: 0.0011 - val_MAPE: 3.8985 - val_loss: 7.2921e-04
# Epoch 39/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 575700.1250 - loss: 8.1758e-04 - val_MAPE: 6.0212 - val_loss: 0.0014
# Epoch 40/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 393513.9688 - loss: 8.7653e-04 - val_MAPE: 8.0006 - val_loss: 0.0029
# Epoch 41/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 438968.4062 - loss: 8.3211e-04 - val_MAPE: 6.2233 - val_loss: 0.0019
# Epoch 42/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 273650.1875 - loss: 7.9510e-04 - val_MAPE: 4.3459 - val_loss: 9.2194e-04
# Epoch 43/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 176236.4219 - loss: 7.9999e-04 - val_MAPE: 5.6470 - val_loss: 0.0017
# Epoch 44/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 416720.8438 - loss: 0.0011 - val_MAPE: 3.4520 - val_loss: 6.7926e-04
# Epoch 45/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 592243.0000 - loss: 7.9356e-04 - val_MAPE: 4.7310 - val_loss: 0.0014
# Epoch 46/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 403765.9375 - loss: 8.9978e-04 - val_MAPE: 4.5113 - val_loss: 0.0012
# Epoch 47/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 802531.0000 - loss: 8.8574e-04 - val_MAPE: 7.1929 - val_loss: 0.0028
# Epoch 48/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 372096.1250 - loss: 8.8822e-04 - val_MAPE: 4.7043 - val_loss: 0.0017
# Epoch 49/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 495763.0312 - loss: 9.6556e-04 - val_MAPE: 6.4278 - val_loss: 0.0027
# Epoch 50/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 342817.6250 - loss: 7.7182e-04 - val_MAPE: 5.0166 - val_loss: 0.0017
# Epoch 1/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - MAPE: 94.1768 - loss: 0.5566 - val_MAPE: 129.3926 - val_loss: 0.2712
# Epoch 2/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 72.5181 - loss: 0.3615 - val_MAPE: 183.8703 - val_loss: 0.3372
# Epoch 3/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 50.2557 - loss: 0.1694 - val_MAPE: 272.5170 - val_loss: 0.4422
# Epoch 4/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 31.4521 - loss: 0.0517 - val_MAPE: 319.3645 - val_loss: 0.5030
# Epoch 5/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 34.0811 - loss: 0.0410 - val_MAPE: 316.4313 - val_loss: 0.4975
# Epoch 6/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 29.6438 - loss: 0.0387 - val_MAPE: 313.6634 - val_loss: 0.4926
# Epoch 7/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 31.4544 - loss: 0.0383 - val_MAPE: 307.5064 - val_loss: 0.4823
# Epoch 8/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 29.9471 - loss: 0.0364 - val_MAPE: 306.6732 - val_loss: 0.4790
# Epoch 9/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 27.8568 - loss: 0.0343 - val_MAPE: 298.4655 - val_loss: 0.4661
# Epoch 10/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 28.3605 - loss: 0.0346 - val_MAPE: 298.2527 - val_loss: 0.4640
# Epoch 11/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 26.2589 - loss: 0.0324 - val_MAPE: 290.2861 - val_loss: 0.4523
# Epoch 12/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 28.8871 - loss: 0.0345 - val_MAPE: 286.9628 - val_loss: 0.4464
# Epoch 13/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 27.4489 - loss: 0.0298 - val_MAPE: 281.1092 - val_loss: 0.4355
# Epoch 14/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 24.8875 - loss: 0.0257 - val_MAPE: 270.4499 - val_loss: 0.4208
# Epoch 15/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 27.1093 - loss: 0.0292 - val_MAPE: 264.5050 - val_loss: 0.4102
# Epoch 16/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 23.8881 - loss: 0.0255 - val_MAPE: 257.1339 - val_loss: 0.3979
# Epoch 17/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 23.2668 - loss: 0.0257 - val_MAPE: 249.5584 - val_loss: 0.3864
# Epoch 18/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 22.0303 - loss: 0.0221 - val_MAPE: 238.7564 - val_loss: 0.3698
# Epoch 19/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 20.8734 - loss: 0.0210 - val_MAPE: 229.3357 - val_loss: 0.3563
# Epoch 20/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 20.0232 - loss: 0.0210 - val_MAPE: 222.7985 - val_loss: 0.3460
# Epoch 21/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 21.2773 - loss: 0.0224 - val_MAPE: 215.5217 - val_loss: 0.3353
# Epoch 22/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 19.7057 - loss: 0.0196 - val_MAPE: 206.5926 - val_loss: 0.3228
# Epoch 23/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 18.5266 - loss: 0.0177 - val_MAPE: 195.4965 - val_loss: 0.3095
# Epoch 24/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 19.0622 - loss: 0.0176 - val_MAPE: 188.5716 - val_loss: 0.3005
# Epoch 25/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 17.5958 - loss: 0.0168 - val_MAPE: 185.2484 - val_loss: 0.2952
# Epoch 26/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.6901 - loss: 0.0136 - val_MAPE: 178.4328 - val_loss: 0.2870
# Epoch 27/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 17.1371 - loss: 0.0150 - val_MAPE: 171.3071 - val_loss: 0.2773
# Epoch 28/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.5587 - loss: 0.0137 - val_MAPE: 167.4090 - val_loss: 0.2728
# Epoch 29/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 14.1938 - loss: 0.0122 - val_MAPE: 164.9260 - val_loss: 0.2700
# Epoch 30/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.2624 - loss: 0.0132 - val_MAPE: 162.6479 - val_loss: 0.2664
# Epoch 31/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.4576 - loss: 0.0112 - val_MAPE: 156.7878 - val_loss: 0.2605
# Epoch 32/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 15.2475 - loss: 0.0128 - val_MAPE: 155.1424 - val_loss: 0.2586
# Epoch 33/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.5789 - loss: 0.0114 - val_MAPE: 153.2186 - val_loss: 0.2552
# Epoch 34/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 12.2025 - loss: 0.0098 - val_MAPE: 150.1327 - val_loss: 0.2528
# Epoch 35/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.1613 - loss: 0.0106 - val_MAPE: 148.7091 - val_loss: 0.2497
# Epoch 36/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.0038 - loss: 0.0111 - val_MAPE: 150.8963 - val_loss: 0.2514
# Epoch 37/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 12.7771 - loss: 0.0092 - val_MAPE: 147.9827 - val_loss: 0.2484
# Epoch 38/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.6746 - loss: 0.0097 - val_MAPE: 144.4457 - val_loss: 0.2435
# Epoch 39/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 12.1305 - loss: 0.0088 - val_MAPE: 143.8375 - val_loss: 0.2432
# Epoch 40/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 10.9707 - loss: 0.0081 - val_MAPE: 144.7483 - val_loss: 0.2429
# Epoch 41/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 11.0804 - loss: 0.0084 - val_MAPE: 146.3153 - val_loss: 0.2444
# Epoch 42/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.2276 - loss: 0.0095 - val_MAPE: 147.2500 - val_loss: 0.2446
# Epoch 43/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 12.7891 - loss: 0.0084 - val_MAPE: 144.0586 - val_loss: 0.2409
# Epoch 44/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 10.2906 - loss: 0.0076 - val_MAPE: 143.1891 - val_loss: 0.2400
# Epoch 45/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 13.5393 - loss: 0.0094 - val_MAPE: 142.7881 - val_loss: 0.2367
# Epoch 46/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 12.2022 - loss: 0.0079 - val_MAPE: 140.3391 - val_loss: 0.2353
# Epoch 47/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 12.6472 - loss: 0.0087 - val_MAPE: 145.3942 - val_loss: 0.2420
# Epoch 48/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 11.8908 - loss: 0.0081 - val_MAPE: 141.1614 - val_loss: 0.2347
# Epoch 49/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 12.8534 - loss: 0.0085 - val_MAPE: 135.5208 - val_loss: 0.2276
# Epoch 50/50
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - MAPE: 11.7738 - loss: 0.0081 - val_MAPE: 136.6927 - val_loss: 0.2279

# %%
# Evaluasi model sebelum denormalisasi
def evaluate_model_before_denormalization(model, X_test, Y_test):
    # Predict
    test_predict = model.predict(X_test, verbose=0)

    # Calculate metrics
    mae = mean_absolute_error(Y_test, test_predict)
    rmse = sqrt(mean_squared_error(Y_test, test_predict))
    mape = mean_absolute_percentage_error(Y_test, test_predict) * 100

    return mae, rmse, mape, Y_test, test_predict

# %%
# Evaluasi model untuk kedua skala
mae_0_1, rmse_0_1, mape_0_1, Y_test_0_1, test_predict_0_1 = evaluate_model_before_denormalization(model_0_1, X_test_0_1, Y_test_0_1)
mae_neg1_1, rmse_neg1_1, mape_neg1_1, Y_test_neg1_1, test_predict_neg1_1 = evaluate_model_before_denormalization(model_neg1_1, X_test_neg1_1, Y_test_neg1_1)

# Print hasil evaluasi
print(f"Interval [0, 1] -> RMSE: {rmse_0_1}, MAPE: {mape_0_1}%")
print(f"Interval [-1, 1] -> RMSE: {rmse_neg1_1}, MAPE: {mape_neg1_1}%")
# Out:
# Interval [0, 1] -> RMSE: 0.041299962603000645, MAPE: 5.016615241765976%
# Interval [-1, 1] -> RMSE: 0.4773514267823907, MAPE: 136.69270277023315%
